# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 115320  Colombo       R Premadasa Stadium
# 115321  Colombo       R Premadasa Stadium
# 115322  Colombo       R Premadasa Stadium
# 115323  Colombo       R Premadasa Stadium
# 115324  Colombo       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city']=cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [63888 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [50501 rows x 7 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# 2       Melbourne              1
# 3       Melbourne              3
# 4       Melbourne              3
# ...           ...            ...
# 115320    Colombo            125
# 115321    Colombo            125
# 115322    Colombo            125
# 115323    Colombo            127
# 115324    Colombo            128
#
# [50501 rows x 8 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# 1       Melbourne              0    0       2
# 2       Melbourne              1    0       3
# 3       Melbourne              3    0       4
# 4       Melbourne              3    0       5
# ...           ...            ...  ...     ...
# 115320    Colombo            125   19       3
# 115321    Colombo            125   19       4
# 115322    Colombo            125   19       5
# 115323    Colombo            127   19       6
# 115324    Colombo            128   19       7
#
# [50501 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled
# 0       Melbourne              0    0       1             1
# 1       Melbourne              0    0       2             2
# 2       Melbourne              1    0       3             3
# 3       Melbourne              3    0       4             4
# 4       Melbourne              3    0       5             5
# ...           ...            ...  ...     ...           ...
# 115320    Colombo            125   19       3           117
# 115321    Colombo            125   19       4           118
# 115322    Colombo            125   19       5           119
# 115323    Colombo            127   19       6           120
# 115324    Colombo            128   19       7           121
#
# [50501 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled  balls_left
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].transform('cumsum')
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                 10
# ...              ...
# 115320             2
# 115321             2
# 115322             1
# 115323             1
# 115324             1
#
# [50501 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left       crr
# 0                 10  0.000000
# 1                 10  0.000000
# 2                 10  2.000000
# 3                 10  4.500000
# 4                 10  3.600000
# ...              ...       ...
# 115320             2  6.410256
# 115321             2  6.355932
# 115322             1  6.302521
# 115323             1  6.350000
# 115324             1  6.347107
#
# [50501 rows x 14 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame

# Convert 'runs' column to numeric, coercing errors to NaN
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# Group by match_id
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []

for match_id in match_ids:
    # Filter out non-numeric values from 'runs' column and then apply rolling window sum
    last_five.extend(groups.get_group(match_id)['runs'].dropna().rolling(window=30).sum().values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# 0       Melbourne              0    0       1             1         119
# 1       Melbourne              0    0       2             2         118
# 2       Melbourne              1    0       3             3         117
# 3       Melbourne              3    0       4             4         116
# 4       Melbourne              3    0       5             5         115
# ...           ...            ...  ...     ...           ...         ...
# 115320    Colombo            125   19       3           117           3
# 115321    Colombo            125   19       4           118           2
# 115322    Colombo            125   19       5           119           1
# 115323    Colombo            127   19       6           120           0
# 115324    Colombo            128   19       7           121           0
#
#         wickets_left       crr  last_five
# 0                 10  0.000000        NaN
# 1                 10  0.000000        NaN
# 2                 10  2.000000        NaN
# 3                 10  4.500000        NaN
# 4                 10  3.600000        NaN
# ...              ...       ...        ...
# 115320             2  6.410256       32.0
# 115321             2  6.355932       32.0
# 115322             1  6.302521       32.0
# 115323             1  6.350000       33.0
# 115324             1  6.347107       32.0
#
# [50501 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 50496             2  6.410256       32.0     128
# 50497             2  6.355932       32.0     128
# 50498             1  6.302521       32.0     128
# 50499             1  6.350000       33.0     128
# 50500             1  6.347107       32.0     128
#
# [50501 rows x 9 columns]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team  bowling_team             city  current_score  balls_left  \
# 45603   New Zealand     Sri Lanka  Mount Maunganui             69          76
# 43878   New Zealand  South Africa        Centurion             79          64
# 38437   New Zealand   West Indies         Auckland            135          28
# 44357     Australia  South Africa           Durban             68          85
# 34215      Pakistan    Bangladesh           Mirpur             89          43
# ...             ...           ...              ...            ...         ...
# 18352     Australia         India           Mumbai            120          24
# 20977  South Africa   West Indies           London            115          40
# 43316       England  South Africa        Cape Town            119          11
# 39214     Sri Lanka  South Africa       Chittagong             42          93
# 36071     Australia      Pakistan            Dubai             61          41
#
#        wickets_left        crr  last_five  runs_x
# 45603            10   9.409091       35.0     182
# 43878             8   8.464286       39.0     177
# 38437             5   8.804348       55.0     189
# 44357             9  11.657143       60.0     157
# 34215             7   6.935065       29.0     135
# ...             ...        ...        ...     ...
# 18352             6   7.500000       33.0     166
# 20977             8   8.625000       44.0     183
# 43316             3   6.550459       37.0     134
# 39214             8   9.333333       42.0     165
# 36071             5   4.632911       15.0      89
#
# [38477 rows x 9 columns]

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team        city  current_score  balls_left  \
# 23059   Bangladesh  West Indies    St Kitts             71          47
# 35922  New Zealand      England  Wellington             57          68
#
#        wickets_left       crr  last_five  runs_x
# 23059             3  5.835616       25.0     118
# 35922             9  6.576923       40.0     139

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 50067     Sri Lanka     Pakistan        Mirpur             26          90
# 14364     Sri Lanka      England   Southampton             89          57
# 41976  South Africa  West Indies  Johannesburg             78          78
# 10749   New Zealand      England    Wellington            138          25
# 47186   Afghanistan    Sri Lanka       Kolkata             61          46
# ...             ...          ...           ...            ...         ...
# 14143       England    Australia   Southampton            117          32
# 24532      Pakistan      England      Barbados             87          44
# 14034  South Africa      England     Cape Town            152          14
# 45117       England     Pakistan         Dubai             54          68
# 20991  South Africa  West Indies        London            147          26
#
#        wickets_left        crr  last_five
# 50067            10   5.200000       26.0
# 14364             6   8.476190       33.0
# 41976             8  11.142857       57.0
# 10749             5   8.715789       40.0
# 47186             6   4.945946       18.0
# ...             ...        ...        ...
# 14143             5   7.977273       27.0
# 24532             6   6.868421       29.0
# 14034             7   8.603774       62.0
# 45117             7   6.230769       35.0
# 20991             7   9.382979       57.0
#
# [30781 rows x 8 columns]

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/bc/43/242432efc3f60052a4a534dc4926b21e236ab4ec8d4920c593da3f65c65d/xgboost-2.0.2-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.2-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.0.2-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 262.6 kB/s eta 0:06:20
#    ---------------------------------------- 0.1/99.8 MB 476.3 kB/s eta 0:03:30
#    ---------------------------------------- 0.2/99.8 MB 981.9 kB/s eta 0:01:42
#    ---------------------------------------- 0.5/99.8 MB 1.8 MB/s eta 0:00:56
#    ---------------------------------------- 0.7/99.8 MB 2.4 MB/s eta 0:00:43
#     --------------------------------------- 1.3/99.8 MB 3.6 MB/s eta 0:00:28
#     --------------------------------------- 1.8/99.8 MB 4.5 MB/s eta 0:00:22
#     --------------------------------------- 2.4/99.8 MB 5.3 MB/s eta 0:00:19
#    - -------------------------------------- 3.0/99.8 MB 5.9 MB/s eta 0:00:17
#    - -------------------------------------- 3.5/99.8 MB 6.4 MB/s eta 0:00:15
#    - -------------------------------------- 4.1/99.8 MB 6.9 MB/s eta 0:00:14
#    - -------------------------------------- 4.6/99.8 MB 7.2 MB/s eta 0:00:14
#    -- ------------------------------------- 5.2/99.8 MB 7.6 MB/s eta 0:00:13
